# %% [markdown]
# ## 02: Process text and counts
#
# This script uses a pretrained [spaCy](https://spacy.io) model to extract entities from JSONL-formatted data and count them. It expects each record to have a `"meta"` dict with a `"utc"` value containing the UTC timestamp. Counts are generated by month and for each entity and saved out as a CSV. For example:
#
# ```csv
# ,2012-01,2012-02
# meat,1011.0,873.0
# salt,805.0,897.0
# chicken,694.0,713.0
# ```
#
# > ⚠️ **Important note:** If you have a lot of data, you probably want to split up your raw data and run multiple jobs in parallel. The next script that calculates the final counts and variance can take a directory of `.csv` files as its input, so reconciling the counts afterwards is no problem.

# %%
SPACY_MODEL = "./tmp_model/model-best"      # path to spaCy model with entity recognizer
DATA_FILE = "./corpusSkillsCleaned.jsonl"      # preprocessed Reddit data created in previous step
OUTPUT_FILE = "./raw_counts.csv"  # path to output file
N_PROCESSES = 16                  # number of processes for multiprocessing
ENTITY_LABEL = "SKILL"           # label of entity to count

# %%
# !pip install spacy srsly pandas
# Out:
# Requirement already satisfied: spacy in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: srsly in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (2.4.6)
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ff/5a/c7359edec58500b35da8dc40a69ea7b0a3be48a479e1c91e8e8d0a2d9aa7/pandas-2.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-2.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: pathy>=0.10.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (1.26.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: six>=1.5 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bruxo/miniconda3/envs/nlp310/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Downloading pandas-2.1.1-cp310-cp310-macosx_11_0_arm64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 9.9 MB/s eta 0:00:000m eta 0:00:01:01:01
# Installing collected packages: pandas
# Successfully installed pandas-2.1.1

# %%
import spacy
from collections import Counter, defaultdict
import srsly
from datetime import datetime
import pandas as pd

# %%
counts = defaultdict(Counter)
nlp = spacy.load(SPACY_MODEL)
data = srsly.read_jsonl(DATA_FILE)

data_tuples = ((eg["text"], eg) for eg in data)
for doc, eg in nlp.pipe(data_tuples, as_tuples=True, n_process=N_PROCESSES):
    timestamp = int(eg["utc"])
    year_month = datetime.utcfromtimestamp(timestamp).strftime("%Y-%m")
    for ent in doc.ents:
        if ent.label_ == ENTITY_LABEL:
            counts[str(ent).lower()][year_month] += 1

df = pd.DataFrame(data=counts).transpose()
df.to_csv(OUTPUT_FILE)
